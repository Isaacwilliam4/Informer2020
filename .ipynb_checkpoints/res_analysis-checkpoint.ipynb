# %%
import numpy as np
import matplotlib.pyplot as plt

filepath = 'informer_custom_ftM_sl6_ll2_pl1_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_tomato_0'
pred = np.load(f'./results/{filepath}/pred.npy')
true = np.load(f'./results/{filepath}/true.npy')

# %%
true[0,23,:]
# Out:
# array([-1.1073383,  0.       ,  1.1073383,  0.       ,  1.1073383,
#        -1.1073383, -1.1073383,  0.       ,  1.1073383, -1.1073383,
#         0.       ,  1.1073383,  0.       ,  1.1073383,  0.       ,
#         0.       ,  0.       ,  1.1073383,  0.       ,  0.       ,
#        -1.1073383,  0.       ,  0.       ,  0.       ,  0.       ,
#         0.       ,  0.       ,  0.       , -1.1073383,  0.       ,
#         0.       ,  1.1073383,  0.       ,  0.       ,  1.1073383,
#         0.       ,  0.       ,  0.       ,  0.       ,  0.       ,
#         1.1073383,  0.       , -1.1073383, -1.1073383,  0.       ,
#         0.       ,  1.1073383,  0.       , -1.1073383,  0.       ,
#         0.       ,  0.       ,  1.1073383,  0.       ,  0.       ,
#        -1.1073383,  0.       ,  1.1073383,  0.       ,  0.       ,
#         0.       ,  0.       ,  0.       ,  0.       ,  0.       ,
#         1.1073383,  0.       ,  0.       ,  1.1073383,  1.1073383,
# ...

# %%
pred[0,23,:]
# Out:
# array([-3.6394450e-01, -1.3133972e-03,  4.1913754e-01, -4.2305447e-02,
#         4.9151951e-01, -5.0351751e-01, -4.7328579e-01,  2.5151450e-02,
#         4.5823798e-01, -4.2075416e-01,  3.2262504e-02,  4.1941878e-01,
#        -3.9551020e-02,  4.9667251e-01, -4.7185760e-02,  2.1011207e-02,
#        -1.4686144e-02,  4.8482054e-01,  4.7329210e-02,  1.9679040e-02,
#        -5.2924627e-01,  1.5439925e-02, -7.9009142e-03,  2.0079950e-02,
#        -2.7045319e-03,  6.0194567e-02, -4.4275358e-02,  1.8615507e-02,
#        -4.9053466e-01,  9.3912594e-02,  2.6665732e-02,  4.6897519e-01,
#        -1.2685195e-02,  6.5326944e-02,  4.3934581e-01, -2.8536143e-03,
#        -6.5769322e-02, -4.4705864e-02, -3.3475540e-03,  4.7941476e-02,
#         4.5576617e-01, -2.9254593e-02, -3.9098069e-01, -4.1891670e-01,
#         4.0308051e-03, -5.5418566e-02,  4.0690967e-01,  1.2957225e-02,
#        -4.6307677e-01, -4.6556368e-02, -6.6635132e-02,  3.5493188e-02,
# ...

# %%
pred.shape
# Out:
# (160, 24, 90)

# %%
y = true[100,:,13]
y_hat = pred[100,:,13]
x = np.arange(len(y))
plt.plot(x,y, label='true')
plt.plot(x,y_hat, label='pred')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_squared_error

pred_ = pred[1,:,:]
true_ = true[1,:,:]

print(mean_absolute_percentage_error(pred_,true_))
print(mean_squared_error(pred_,true_))
# Out:
# 1.6066773
# 0.1658036

# %%
mean_absolute_percentage_error([60],[100])
# Out:
# 0.6666666666666666

# %%
print(pred[99,3,0])
print(true[99,3,0])
# Out:
# 0.19544838
# 1.3866237
